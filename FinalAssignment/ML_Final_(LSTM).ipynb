# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanas97/ml/blob/master/FinalAssignment/ML_Final_(LSTM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA PREPARATION

# %% [markdown]
# ### Import Library.

# %%
import pandas as pd
import numpy as np
import string
from string import digits
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import keras
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model
from nltk.translate.bleu_score import corpus_bleu

# %%
import time

class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, epoch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive  sample_data

# %% [markdown]
# ### Pre-process Dataset

# %%
line= pd.read_table('/content/drive/My Drive/de.txt', names=['deu'], nrows=19250, skip_blank_lines=False)
line2= pd.read_table('/content/drive/My Drive/en.txt', names=['en'], nrows=19250, skip_blank_lines=False)
# print(line[::-1])
# print(lines[::-1])
linesx = pd.concat([line, line2], axis=1)
lines = pd.concat([linesx, linesx])  
print(lines[::])
# Out:
#                                                      deu                                                 en
# 0      SAN FRANCISCO – Es war noch nie leicht, ein ra...  SAN FRANCISCO – It has never been easy to have...
# 1      In letzter Zeit allerdings ist dies schwierige...  Lately, with gold prices up more than 300% ove...
# 2      Erst letzten Dezember verfassten meine Kollege...  Just last December, fellow economists Martin F...
# 3                      Und es kam, wie es kommen musste.                              Wouldn’t you know it?
# 4      Seit der Veröffentlichung ihrer Artikel ist de...  Since their articles appeared, the price of go...
# 5      Jüngst erreichte er sogar ein Rekordhoch von 1...  Gold prices even hit a record-high $1,300 rece...
# 6      Im letzten Dezember argumentierten die Goldbug...  Last December, many gold bugs were arguing tha...
# 7      Beflügelt aufgrund des anhaltenden Aufwärtstre...  Now, emboldened by continuing appreciation, so...
# 8      Ein erfolgreicher Gold-Investor erklärte mir v...  One successful gold investor recently explaine...
# 9      Seit damals ist er auf über 10.000 Punkte gest...    Since then, the index has climbed above 10,000.
# 10     Nun hat Gold die magische Grenze von 1.000 Dol...  Now that gold has crossed the magic $1,000 bar...
# 11     Zugegeben: Es bedarf keiner großen Fantasie, u...  Admittedly, getting to a much higher price for...
# 12     Denn inflationsbereinigt erreicht der Goldprei...  After adjusting for inflation, today’s price i...
# 13     Damals lag Gold bei 850 Dollar, also in heutig...  Back then, gold hit $850, or well over $2,000 ...
# 14     Allerdings gab es im Januar 1980 offensichtlic...  But January 1980 was arguably a “freak peak” d...
# 15     Bei einem Wert von 1.300 Dollar ist der heutig...  At $1,300, today’s price is probably more than...
# 16     Was also könnte einen weiteren kolossalen Anst...  So what could justify another huge increase in...
# 17     Eine Möglichkeit wäre natürlich der totale Zus...  One answer, of course, is a complete collapse ...
# 18     Angesichts ausufernder Defizite und einer rich...  With soaring deficits, and a rudderless fiscal...
# 19     Und wer sich in dieser Hinsicht wirklich Sorge...  And if you are really worried about that, gold...
# 20     Natürlich kann man einwenden, dass inflationsi...  Sure, some might argue that inflation-indexed ...
# 21     Aber die Goldbugs machen sich zu Recht Sorgen,...  But gold bugs are right to worry about whether...
# 22     Wie Carmen Reinhart und ich in unserem jüngste...  In fact, as Carmen Reinhart and I discuss in o...
# 23     Sogar in den Vereinigten Staaten wurden währen...  Even the United States abrogated indexation cl...

# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
lines = lines.dropna()

# %%
# Remove special characters
lines.en=lines.en.apply(lambda x: re.sub("'", '', x))
lines.en=lines.en.apply(lambda x: re.sub("’", '', x))
lines.en=lines.en.apply(lambda x: re.sub("“", '', x))
lines.en=lines.en.apply(lambda x: re.sub("”", '', x))
lines.en=lines.en.apply(lambda x: re.sub("„", '', x))
lines.en=lines.en.apply(lambda x: re.sub("–", '', x))

lines.deu=lines.deu.apply(lambda x: re.sub("'", '', x))
lines.deu=lines.deu.apply(lambda x: re.sub("’", '', x))
lines.deu=lines.deu.apply(lambda x: re.sub("“", '', x))
lines.deu=lines.deu.apply(lambda x: re.sub("”", '', x))
lines.deu=lines.deu.apply(lambda x: re.sub("„", '', x))
lines.deu=lines.deu.apply(lambda x: re.sub("–", '', x))

# %%
# Remove all numbers from text
remove_digits = str.maketrans('', '', digits)
lines.en=lines.en.apply(lambda x: x.translate(remove_digits))
lines.deu = lines.deu.apply(lambda x: x.translate(remove_digits))

# %%
# Remove extra spaces
lines.en=lines.en.apply(lambda x: x.strip())
lines.deu=lines.deu.apply(lambda x: x.strip())
lines.en=lines.en.apply(lambda x: re.sub(" +", " ", x))
lines.deu=lines.deu.apply(lambda x: re.sub(" +", " ", x))

# %%
exclude = set(string.punctuation) 
# Remove punctuations
lines.en=lines.en.apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
lines.deu=lines.deu.apply(lambda x: ''.join(ch for ch in x if ch not in exclude))

# %%
# Lowercase all characters
lines.en=lines.en.apply(lambda x: x.lower())
lines.deu=lines.deu.apply(lambda x: x.lower())

# %%
# Filter Word Length
min_word_len = 1
max_word_len = 18
lines['deu'] = lines['deu'].astype('str')
lines['en'] = lines['en'].astype('str')
mask = ((lines['deu'].str.split().str.len() <= max_word_len) & (lines['en'].str.split().str.len() <= max_word_len) & (lines['deu'].str.split().str.len() >= min_word_len) & (lines['en'].str.split().str.len() >= min_word_len))
# print(mask)
lines = lines.loc[mask]

# %%
# Add start and end tokens to target sequences
lines.en = lines.en.apply(lambda x : 'START_ '+ x + ' _END')

# %%
print("Total Sentences EN : ",len(lines.en))
print("Total Sentences DEU : ",len(lines.deu))
# Out:
# Total Sentences EN :  14004
# Total Sentences DEU :  14004

# %% [markdown]
#   ### Visualize Data.

# %%
# empty lists
eng_l = []
deu_l = []

# populate the lists with sentence lengths
for i in lines.en:
    eng_l.append(len(i.split()))

for i in lines.deu:
    deu_l.append(len(i.split()))
    
print((eng_l)) 
print((deu_l))
# Out:
# %%
length_df = pd.DataFrame({'eng':eng_l, 'deu':deu_l})
print(len(eng_l),len(deu_l))
print(max(eng_l),max(deu_l))
# Out:
# 14004 14004
# 20 18

# %%
length_df.hist(bins = 50)
plt.show()

# %%
lines.sample(10)
# Out:
#                                                      deu                                                 en
# 19096  einige führen dies auf die tatsache zurück das...  START_ some attribute this to the fact that in...
# 5850      und dennoch kann das durchaus wieder passieren    START_ and yet that could very well happen _END
# 19203  mir wird die ehre zuteil dem generalsekretär a...  START_ i have the honor to serve as the secret...
# 18911  dafür wurden sie bestraft indem man ihnen kein...  START_ they were then punished for a few years...
# 10494  der wiederaufbau des landes ist nicht billig z...  START_ rebuilding the country cannot be done c...
# 17057  argentiniens produzenten konnten sogar dann wa...  START_ argentine producers could sell goods to...
# 3807   mit anderen worten der hauptzweck der liga ist...  START_ in other words the leagues main purpose...
# 15903  wie in vielen anderen ländern der welt hängt s...  START_ its social fabric like that of many oth...
# 9629   heute aber fließen geldmittel aus afrika zu de...  START_ but today resources flow from africa to...
# 4815   die erste heilige allianz war eine schöpfung d...  START_ the first holy alliance was a creation ...

# %% [markdown]
#   ### Training Preparation.

# %%
# Vocabulary of English
all_en_words=set()
for en in lines.en:
    for word in en.split():
        if word not in all_en_words:
            all_en_words.add(word)

# Vocabulary of Deutsch 
all_deu_words=set()
for deu in lines.deu:
    for word in deu.split():
        if word not in all_deu_words:
            all_deu_words.add(word)

# %%
# Max Length of source sequence
max_length_src = np.max(deu_l)
max_length_src
# Out:
# 18

# %%
# Max Length of target sequence
max_length_tar = np.max(eng_l)
max_length_tar
# Out:
# 20

# %%
input_words = sorted(list(all_deu_words))
target_words = sorted(list(all_en_words))
num_encoder_tokens = len(all_deu_words)
num_decoder_tokens = len(all_en_words)
num_encoder_tokens, num_decoder_tokens
# Out:
# (14617, 10003)

# %%
num_decoder_tokens += 1 # For zero padding
num_decoder_tokens
# Out:
# 10004

# %%
print("Total Sentences EN : ",len(lines.en))
print("Total Sentences DEU : ",len(lines.deu))
# Out:
# Total Sentences EN :  14004
# Total Sentences DEU :  14004

# %%
input_token_index = dict([(word, i+1) for i, word in enumerate(input_words)])
target_token_index = dict([(word, i+1) for i, word in enumerate(target_words)])

# %%
reverse_input_char_index = dict((i, word) for word, i in input_token_index.items())
reverse_target_char_index = dict((i, word) for word, i in target_token_index.items())
print(reverse_input_char_index)
print(reverse_target_char_index)
# Out:
# {1: 'a', 2: 'ab', 3: 'abba', 4: 'abbas', 5: 'abbau', 6: 'abbauen', 7: 'abbekommen', 8: 'abchasien', 9: 'abdrücken', 10: 'abduktiv', 11: 'abduktive', 12: 'abe', 13: 'abebben', 14: 'abends', 15: 'abenteuerlichen', 16: 'aber', 17: 'abfedernde', 18: 'abfedert', 19: 'abfederung', 20: 'abfederungalleineiner', 21: 'abfeuern', 22: 'abfließen', 23: 'abfluss', 24: 'abgaben', 25: 'abgang', 26: 'abgebaut', 27: 'abgeben', 28: 'abgefunden', 29: 'abgegeben', 30: 'abgehalten', 31: 'abgehoben', 32: 'abgeht', 33: 'abgelaufen', 34: 'abgelegenen', 35: 'abgelegt', 36: 'abgelehnt', 37: 'abgeleistet', 38: 'abgeleitet', 39: 'abgelenkt', 40: 'abgemacht', 41: 'abgeordnete', 42: 'abgerutscht', 43: 'abgeschafft', 44: 'abgeschlossen', 45: 'abgeschotteten', 46: 'abgeschworen', 47: 'abgesehen', 48: 'abgesichert', 49: 'abgestaubt', 50: 'abgestempelt', 51: 'abgestimmt', 52: 'abgestraft', 53: 'abgetan', 54: 'abgewehrt', 55: 'abgewickelt', 56: 'abgeändert', 57: 'abgibt', 58: 'abgleiten', 59: 'abgleitet', 60: 'abgrund', 61: 'abgrunds', 62: 'abhalten', 63: 'abhanden', 64: 'abhilfe', 65: 'abholzung', 66: 'abholzungsteams', 67: 'abhält', 68: 'abhängig', 69: 'abhängiger', 70: 'abhängigkeit', 71: 'abhängigkeitsrisiko', 72: 'abhängt', 73: 'abhöraktionen', 74: 'abkommen', 75: 'abkommens', 76: 'abkoppeln', 77: 'abkopplung', 78: 'abkürzung', 79: 'abkürzungen', 80: 'ablassen', 81: 'ablaufen', 82: 'ableben', 83: 'ablehnen', 84: 'ablehnung', 85: 'ablenken', 86: 'abläufe', 87: 'abmachung', 88: 'abmvertrag', 89: 'abnahme', 90: 'abnahmen', 91: 'abnehmen', 92: 'abnehmenden', 93: 'abnehmendes', 94: 'abnimmt', 95: 'abraham', 96: 'abrufbar', 97: 'abrupt', 98: 'abrupte', 99: 'abrutschte', 100: 'abrücken', 101: 'abrüstung', 102: 'abrüstungsabkommen', 103: 'absatz', 104: 'absaßen', 105: 'abschaffung', 106: 'abscheu', 107: 'abschied', 108: 'abschlachten', 109: 'abschließenden', 110: 'abschluss', 111: 'abschlussdokument', 112: 'abschneiden', 113: 'abschottung', 114: 'abschreckend', 115: 'abschreckende', 116: 'abschreckung', 117: 'abschreibungen', 118: 'abschussfahrzeugen', 119: 'abschwung', 120: 'abschwunges', 121: 'abschwungs', 122: 'abschwächung', 123: 'abschwören', 124: 'abschätzen', 125: 'absehbarer', 126: 'absenkt', 127: 'absetzung', 128: 'absichern', 129: 'absicherung', 130: 'absicht', 131: 'absichten', 132: 'absichtliche', 133: 'absolut', 134: 'absolute', 135: 'absolutistischer', 136: 'absorbieren', 137: 'abspaltungsbefürworter', 138: 'abspielt', 139: 'abstammung', 140: 'abstand', 141: 'abstecken', 142: 'abstieg', 143: 'abstimmung', 144: 'abstrakt', 145: 'abstürzen', 146: 'absurd', 147: 'absurde', 148: 'absurdität', 149: 'abträglich', 150: 'abverlangt', 151: 'abwandern', 152: 'abwarten', 153: 'abwasser', 154: 'abwassermanagement', 155: 'abwassersysteme', 156: 'abwegig', 157: 'abwegiger', 158: 'abweichen', 159: 'abweichende', 160: 'abweichenden', 161: 'abweichungen', 162: 'abwenden', 163: 'abwerten', 164: 'abwertung', 165: 'abwertungen', 166: 'abwichen', 167: 'abwägen', 168: 'abwärts', 169: 'abwärtsspirale', 170: 'abwärtstrend', 171: 'abzeichnende', 172: 'abzielen', 173: 'abzubauen', 174: 'abzudecken', 175: 'abzufinden', 176: 'abzug', 177: 'abzugeben', 178: 'abzugleiten', 179: 'abzugspläne', 180: 'abzuhalten', 181: 'abzuheben', 182: 'abzuleiten', 183: 'abzurücken', 184: 'abzuschaffen', 185: 'abzuschätzen', 186: 'abzutreiben', 187: 'abzutrennen', 188: 'abzuwarten', 189: 'abzuwechseln', 190: 'abzuwenden', 191: 'abzuwerten', 192: 'abzuzahlen', 193: 'abzuzeichnen', 194: 'abzuziehen', 195: 'abzüge', 196: 'account', 197: 'accra', 198: 'achillesferse', 199: 'achsenmächte', 200: 'acht', 201: 'achten', 202: 'achthundert', 203: 'achtung', 204: 'achtzig', 205: 'achtzigerjahren', 206: 'acmecs', 207: 'act', 208: 'action', 209: 'actionprogramme', 210: 'adaptive', 211: 'adb', 212: 'addiert', 213: 'administration', 214: 'administrativen', 215: 'adventures', 216: 'adventuresteam', 217: 'adäquate', 218: 'adäquater', 219: 'affen', 220: 'affirmative', 221: 'afghanen', 222: 'afghanische', 223: 'afgha ...
# {1: 'START_', 2: '_END', 3: 'a', 4: 'aback', 5: 'abandon', 6: 'abandoned', 7: 'abandoning', 8: 'abba', 9: 'abbas', 10: 'abduction', 11: 'abductive', 12: 'abe', 13: 'abiding', 14: 'ability', 15: 'abkhazia', 16: 'able', 17: 'ably', 18: 'abm', 19: 'abmtreaty', 20: 'abort', 21: 'abound', 22: 'about', 23: 'above', 24: 'abovetrend', 25: 'abraham', 26: 'abroad', 27: 'abruptly', 28: 'absence', 29: 'absent', 30: 'absentee', 31: 'absolute', 32: 'absolutely', 33: 'absolutist', 34: 'absolutists', 35: 'absolved', 36: 'absorber', 37: 'absorbing', 38: 'abstract', 39: 'abstractions', 40: 'absurd', 41: 'absurdity', 42: 'abundant', 43: 'abuse', 44: 'abuses', 45: 'abusive', 46: 'abyss', 47: 'academic', 48: 'accelerate', 49: 'accelerated', 50: 'accelerates', 51: 'accelerating', 52: 'accept', 53: 'acceptable', 54: 'acceptance', 55: 'accepted', 56: 'accepting', 57: 'accepts', 58: 'access', 59: 'accessible', 60: 'accession', 61: 'accessories', 62: 'accident', 63: 'accidents', 64: 'accolades', 65: 'accommodate', 66: 'accommodated', 67: 'accompanied', 68: 'accompanying', 69: 'accomplish', 70: 'accomplishments', 71: 'accord', 72: 'according', 73: 'accordingly', 74: 'account', 75: 'accountability', 76: 'accountable', 77: 'accounting', 78: 'accounts', 79: 'accra', 80: 'accumulate', 81: 'accumulated', 82: 'accumulates', 83: 'accumulation', 84: 'accurate', 85: 'accurately', 86: 'accusation', 87: 'accuse', 88: 'accused', 89: 'accusing', 90: 'achievable', 91: 'achieve', 92: 'achieved', 93: 'achievement', 94: 'achievements', 95: 'achieving', 96: 'achilles', 97: 'acknowledge', 98: 'acknowledged', 99: 'acknowledges', 100: 'acknowledging', 101: 'acquiescing', 102: 'acquisitions', 103: 'acre', 104: 'acres', 105: 'acronym', 106: 'acronyms', 107: 'across', 108: 'act', 109: 'acting', 110: 'action', 111: 'actions', 112: 'active', 113: 'activist', 114: 'activists', 115: 'activities', 116: 'activity', 117: 'activitys', 118: 'actor', 119: 'actors', 120: 'acts', 121: 'actual', 122: 'actually', 123: 'acute', 124: 'acutely', 125: 'adage', 126: 'adapt', 127: 'adaptable', 128: 'adaptation', 129: 'adaptations', 130: 'adaptive', 131: 'adb', 132: 'adbs', 133: 'add', 134: 'added', 135: 'addiction', 136: 'adding', 137: 'addition', 138: 'additional', 139: 'address', 140: 'addressed', 141: 'addresses', 142: 'addressing', 143: 'adds', 144: 'adept', 145: 'adequate', 146: 'adequately', 147: 'adherents', 148: 'adhesive', 149: 'adjust', 150: 'adjusted', 151: 'adjusting', 152: 'adjustment', 153: 'adjustments', 154: 'administration', 155: 'administrations', 156: 'administrative', 157: 'administrators', 158: 'admirers', 159: 'admission', 160: 'admit', 161: 'admitted', 162: 'admittedly', 163: 'adolf', 164: 'adopt', 165: 'adopted', 166: 'adopting', 167: 'adoption', 168: 'advance', 169: 'advanced', 170: 'advancedcountry', 171: 'advances', 172: 'advantage', 173: 'advantages', 174: 'advent', 175: 'adventures', 176: 'adventurous', 177: 'adversaries', 178: 'adverse', 179: 'adversely', 180: 'advertisement', 181: 'advertisements', 182: 'advice', 183: 'adviser', 184: 'advisers', 185: 'advisor', 186: 'advisory', 187: 'advocate', 188: 'advocated', 189: 'advocates', 190: 'advocating', 191: 'aerial', 192: 'afar', 193: 'affair', 194: 'affairs', 195: 'affect', 196: 'affected', 197: 'affecting', 198: 'affects', 199: 'affiliation', 200: 'affirmative', 201: 'afflicting', 202: 'afflicts', 203: 'affluent', 204: 'afford', 205: 'affordable', 206: 'afforded', 207: 'afghan', 208: 'afghanistan', 209: 'afghanistans', 210: 'afghans', 211: 'afraid', 212: 'africa', 213: 'african', 214: 'africanamerican', 215: 'africans', 216: 'africas', 217: 'after', 218: 'afterlife', 219: 'aftermath', 220: 'aftertax', 221: 'afterward', 222: 'again', 223: 'against', 224: 'age', 225: 'aged', 226: 'agencies', 227: 'agency', 228: 'agenda', 229: 'agendas', 230: 'agent', 231: 'agents', 232: 'ages', 233: 'aggravate', 234: 'aggravated', 235: 'aggregate', 236: 'aggressive', 237: 'aggressively', 238: 'aggressors', 239: 'aging', 240: 'ago', 241: ...

# %%
lines = shuffle(lines)
lines.head(10)
# Out:
#                                                      deu                                                 en
# 5753   die investitionen folgen einer erholung eher w...  START_ investments tend to follow recovery as ...
# 11004  die argumente dagegen könige und königinnen zu...  START_ the arguments against maintaining kings...
# 4206   das euroipo brach zusammen weil es zu einer ze...  START_ the euro ipo crashed because it came at...
# 9071   perverserweise sind einige provinzgouverneure ...  START_ perversely some provincial governors an...
# 1889   in diesem sinne wendet sich die erfahrung vene...  START_ in this sense venezuelas experience spe...
# 203    dies ist ein natürliches nebenprodukt der kons...  START_ this is a natural byproduct of consolid...
# 18003  die großen wachstumsstarken schwellenländer ha...  START_ the large highgrowth emerging economies...
# 4670   nehmen wir eines der hauptziele der lissabonst...  START_ consider one of the main purposes of th...
# 16871  das niedrige preisniveau auf dem rohstoffmarkt...  START_ low world commodities prices and protec...
# 4702   die eu hat jährlich über  milliarden investier...  START_ the eu invested upwards of  billion a y...

# %%
# Train - Test Split
X, y = lines.deu, lines.en
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)
X_train.shape, X_test.shape
# Out:
# ((12603,), (1401,))

# %% [markdown]
# ### Data Batch Generator Function

# %%
def generate_batch(X = X_train, y = y_train):
    ''' Generate a batch of data '''
    while True:
        for j in range(0, len(X), batch_size):
            encoder_input_data = np.zeros((batch_size, max_length_src),dtype='float32')
            decoder_input_data = np.zeros((batch_size, max_length_tar),dtype='float32')
            decoder_target_data = np.zeros((batch_size, max_length_tar, num_decoder_tokens),dtype='float32')
            for i, (input_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):
                for t, word in enumerate(input_text.split()):
                    encoder_input_data[i, t] = input_token_index[word] # encoder input seq
                for t, word in enumerate(target_text.split()):
                    if t<len(target_text.split())-1:
                        decoder_input_data[i, t] = target_token_index[word] # decoder input seq
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the START_ token
                        # Offset by one timestep
                        decoder_target_data[i, t - 1, target_token_index[word]] = 1.
            yield([encoder_input_data, decoder_input_data], decoder_target_data)

# %% [markdown]
# ## MODEL BUILDING

# %% [markdown]
# ### Encoder - Decoder LSTM

# %%
latent_dim = 200

# Encoder
encoder_inputs = Input(shape=(None,))
enc_emb =  Embedding(num_encoder_tokens, latent_dim, mask_zero = True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(num_decoder_tokens, latent_dim, mask_zero = True)
dec_emb = dec_emb_layer(decoder_inputs)
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ### Model Execution

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

# %%
train_samples = len(X_train)
val_samples = len(X_test)
batch_size = 384
epochs = 100
time_callback = TimeHistory()

history = model.fit_generator(generator = generate_batch(X_train, y_train),
                    steps_per_epoch = train_samples//batch_size,
                    epochs=epochs, 
                    callbacks=[time_callback],
                    validation_data = generate_batch(X_test, y_test),
                    validation_steps = val_samples//batch_size)
model.save_weights('lstm_weights.h5')
# Out:
# Epoch 1/100
# 32/32 [==============================] - 15s 482ms/step - loss: 7.2062 - acc: 0.1017 - val_loss: 6.7055 - val_acc: 0.1205
# Epoch 2/100
# 32/32 [==============================] - 11s 354ms/step - loss: 6.6337 - acc: 0.1164 - val_loss: 6.5603 - val_acc: 0.1220
# Epoch 3/100
# 32/32 [==============================] - 11s 353ms/step - loss: 6.4986 - acc: 0.1187 - val_loss: 6.4733 - val_acc: 0.1221
# Epoch 4/100
# 32/32 [==============================] - 11s 353ms/step - loss: 6.3917 - acc: 0.1205 - val_loss: 6.4171 - val_acc: 0.1273
# Epoch 5/100
# 32/32 [==============================] - 11s 356ms/step - loss: 6.2939 - acc: 0.1291 - val_loss: 6.3405 - val_acc: 0.1339
# Epoch 6/100
# 32/32 [==============================] - 11s 354ms/step - loss: 6.2068 - acc: 0.1343 - val_loss: 6.2739 - val_acc: 0.1396
# Epoch 7/100
# 32/32 [==============================] - 11s 355ms/step - loss: 6.1205 - acc: 0.1407 - val_loss: 6.1961 - val_acc: 0.1463
# Epoch 8/100
100
# 32/32 [==============================] - 11s 356ms/step - loss: 0.4644 - acc: 0.9399 - val_loss: 1.8009 - val_acc: 0.7238
# Epoch 93/100
# 32/32 [==============================] - 11s 353ms/step - loss: 0.4402 - acc: 0.9441 - val_loss: 1.7477 - val_acc: 0.7386
# Epoch 94/100
# 32/32 [==============================] - 11s 351ms/step - loss: 0.4189 - acc: 0.9480 - val_loss: 1.7699 - val_acc: 0.7330
# Epoch 95/100
# 32/32 [==============================] - 11s 350ms/step - loss: 0.3994 - acc: 0.9508 - val_loss: 1.6767 - val_acc: 0.7581
# Epoch 96/100
# 32/32 [==============================] - 11s 351ms/step - loss: 0.3775 - acc: 0.9547 - val_loss: 1.6322 - val_acc: 0.7675
# Epoch 97/100
# 32/32 [==============================] - 11s 352ms/step - loss: 0.3563 - acc: 0.9581 - val_loss: 1.6091 - val_acc: 0.7736
# Epoch 98/100
# 32/32 [==============================] - 11s 356ms/step - loss: 0.3372 - acc: 0.9620 - val_loss: 1.5955 - val_acc: 0.7789
# Epoch 99/100
# 32/32 [==============================] - 11s 359ms/step - loss: 0.3197 - acc: 0.9645 - val_loss: 1.5290 - val_acc: 0.7936
# Epoch 100/100
# 32/32 [==============================] - 11s 353ms/step - loss: 0.3025 - acc: 0.9671 - val_loss: 1.5108 - val_acc: 0.7913

# %% [markdown]
# ### Load the weights

# %%
model.load_weights('lstm_weights.h5')

# %% [markdown]
# ### Inference Setup

# %%
# Encode the input sequence to get the "thought vectors"
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2= dec_emb_layer(decoder_inputs) # Get the embeddings of the decoder sequence

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2) # A dense softmax layer to generate prob dist. over the target vocabulary

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# %% [markdown]
# ### Decode sample sequeces

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0] = target_token_index['START_']

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += ' '+sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '_END' or
           len(decoded_sentence) > 50):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# #### Result and Evaluation on Train Dataset

# %%
batch_size=1

# %%
train_gen = generate_batch(X_train, y_train)

# %%
ref = []
can = []

for k in range(50):
    (input_seq, actual_output), _ = next(train_gen)
#     print(input_seq)
#     print(np.shape(input_seq))
#     print(actual_output)
#     print(np.shape(actual_output))
#     print(_)
    decoded_sentence = decode_sequence(input_seq)
    print('Input Deutch sentence:', X_train[k:k+1].values[0])
    print('Actual English Translation:', y_train[k:k+1].values[0][6:-4])
    ref.append([y_train[k:k+1].values[0][6:-4].split()])
    print('Predicted English Translation:', decoded_sentence[:-4])
    can.append(decoded_sentence[:-4].split())
    print("-----------------------------------------")
    
print(ref)
print(can)
# Out:
# Input Deutch sentence: in schweden wurden gesetze verabschiedet die die bürokratie für unternehmen mit bedarf an ausländischen arbeitskräften minimieren
# Actual English Translation:  sweden has developed legislation that minimizes bureaucracy for companies that need foreign workers
# Predicted English Translation:  sweden has developed legislation that minimizes bureauc
# -----------------------------------------
# Input Deutch sentence: der unberechenbare kutschma verdient solche sicherheitsmaßnahmen zur überwachung seines wohlverhaltens noch viel mehr
# Actual English Translation:  the wayward kuchma is far more deserving of europe imposing safeguards to ensure his good behavior
# Predicted English Translation:  the wayward kuchma is far more deserving of eu
# -----------------------------------------
# Input Deutch sentence: im zuge der globalisierung konnten große familienunternehmen ihre größe und ihren räumlichen einfluss steigern
# Actual English Translation:  as a result of globalization large family firms could increase their size and their geographic range
# Predicted English Translation:  as a result of globalization large family firms c
# -----------------------------------------
# Input Deutch sentence: was haben die beiden das anderen kandidaten abgeht und das so viele amerikaner offenbar wollen
# Actual English Translation:  what do they have that other candidates dont and that so many americans seem to want
# Predicted English Translation:  what do they have that many candidates dont wan
# -----------------------------------------
# Input Deutch sentence: eine gesunde ältere person könnte sich durchaus über teilzeitarbeit freuen wenn sie flexibel genug gestaltet ist
# Actual English Translation:  a healthy older person may well appreciate parttime work if it comes with flexibility
# Predicted English Translation:  a healthy older person may well appreciate part
# -----------------------------------------
# Input Deutch sentence: george w bushs verhängnisvoller krieg gegen den irak hat europa in eine schwierige lage gebracht
# Actual English Translation:  george w bushs disastrous war in iraq has put europe in a bind
# Predicted English Translation:  george w bushs disastrous war in iraq has put eu
# -----------------------------------------
# Input Deutch sentence: doch kann sich dieselbe kritik gegen sarkozy richten
# Actual English Translation:  but the same criticism can be directed at sarkozy
# Predicted English Translation:  but the same criticism can be directed at sarkozy
# -----------------------------------------
# Input Deutch sentence: doch die buchführung nach iwfrichtlinien verbietet die verwendung dieser vermögen um die wirtschaft durch antizyklische staatsausgaben zu stabilisieren
# Actual English Translation:  but imf accounting inhibits the use of these funds to help stabilize an economy through countercyclical fiscal spending
# Predicted English Translation:  but imf accounting inhibits the use of these f
# -----------------------------------------
# Input Deutch sentence: zudem war mubarak alt und krank und hatte das vertrauen seines volkes verloren
# Actual English Translation:  furthermore mubarak was old and sick and no longer enjoyed the trust of his people
# Predicted English Translation:  furthermore mubarak was old and sick and no lo
# -----------------------------------------
# Input Deutch sentence: in hongkong gingen die exporte im september um  zurück der erste rückgang im vergleich zum vorjahr in monaten
# Actual English Translation:  in hong kong exports actually contracted by  in september the first yearonyear decline in months
# Predicted English Translation:  in hong kong exports actually contracted by in septe
# -----------------------------------------
# Input Deutch sentence: dies ist leider keine überraschung
# Actual English Translation:  unfortunately that is no surprise
# Predicted English Translation:  unfortunately that is no surprise
# -----------------------------------------
# Input Deutch sentence: noch nie hat amerika der weltgrößte verbraucher so lange geschwächelt
# Actual English Translation:  never before has america the worlds biggest consumer been so weak for so long
# Predicted English Translation:  never before has the worlds biggest consumer bee
# -----------------------------------------
# Input Deutch sentence: ein trauriges faktum ist dass die mehrheit der eubürger gegen einen türkischen beitritt ist
# Actual English Translation:  it is a sad fact that a large majority of voters in the eu are against turkish membership
# Predicted English Translation:  it is a sad fact that a large majority of the f
# -----------------------------------------
# Input Deutch sentence: kohlenstofffreie stromerzeugung aus wasserkraft ist für subsaharaafrika daher die folgerichtige energiequelle
# Actual English Translation:  carbonfree hydroelectric power is the right choice as subsaharan africas principal source of energy
# Predicted English Translation:  carbonfree hydroelectric power is the right ch
# -----------------------------------------
# Input Deutch sentence: andere schätzungen gehen von einer niedrigeren aber immer noch alarmierenden quote von  aus
# Actual English Translation:  others estimate a lower but still alarming rate of
# Predicted English Translation:  others estimate a lower but still alarming rat
# -----------------------------------------
# Input Deutch sentence: nichts könnte abwegiger sein
# Actual English Translation:  nothing could be more incorrect
# Predicted English Translation:  nothing could be more incorrect
# -----------------------------------------
# Input Deutch sentence: in den letzten zwei jahrzehnten haben die regierungen nicht genügend lösungen für umweltbedrohungen geliefert
# Actual English Translation:  in the past two decades governments have come up short on solutions to environmental threats
# Predicted English Translation:  in the past two decades governments have come up s
# -----------------------------------------
# Input Deutch sentence: wenn sich beide flügel zusammengeschlossen hätten wäre diese einzelne partei vielleicht als unschlagbare kraft daraus hervorgegangen
# Actual English Translation:  perhaps if both wings had united that single party would have appeared as an unbeatable juggernaut
# Predicted English Translation:  perhaps if both wings had united that single p
# -----------------------------------------
# Input Deutch sentence: subventionen und handelsschranken
# Actual English Translation:  subsidies and trade barriers
# Predicted English Translation:  subsidies and trade barriers
# -----------------------------------------
# Input Deutch sentence: tatsächlich ist die erwartung derartiger resultate innerhalb der angepeilten frist von vier monaten höchst unplausibel
# Actual English Translation:  indeed to expect such results by the proposed fourmonth deadline is highly implausible
# Predicted English Translation:  indeed to expect such results by the proposed fourm
# -----------------------------------------
# Input Deutch sentence: zehn jahre später jedoch versucht eben dieser señor cavallo die rezession und die staatliche zahlungsunfähigkeit abzuwenden
# Actual English Translation:  yet ten years later the same signor cavallo is trying to fend off recession and government default
# Predicted English Translation:  yet ten years later the same signor cavallo is tr
# -----------------------------------------
# Input Deutch sentence: die aktuellen hilfsstrukturen sind nicht ausreichend
# Actual English Translation:  the current aid structures are inadequate
# Predicted English Translation:  the current aid structures are inadequate
# -----------------------------------------
# Input Deutch sentence: seit der gründung der vereinten nationen im jahr hat sich die weltbevölkerung verdreifacht
# Actual English Translation:  the worlds population has tripled since the united nations was created in
# Predicted English Translation:  the worlds population has tripled since the un
# -----------------------------------------
# Input Deutch sentence: doch eine erholung des wirtschaftswachstums ist kurzfristig unwahrscheinlich
# Actual English Translation:  but a revival of economic growth in the short term is unlikely
# Predicted English Translation:  but a few time at least this is different for amer
# -----------------------------------------
# Input Deutch sentence: für den südlichen rand der eurozone freilich ist schon der jetzige eurokurs schwer zu bewältigen
# Actual English Translation:  for the eurozones southern periphery however todays euro rate is very difficult to manage
# Predicted English Translation:  for the eurozones southern periphery however to
# -----------------------------------------
# Input Deutch sentence: präsident barack obama setzt den vertrauensmultiplikator ein und behauptet die rezession eingedämmt zu haben
# Actual English Translation:  president barack obama has deployed the confidence multiplier and claims to have contained the recession
# Predicted English Translation:  president barack obama has deployed the confid
# -----------------------------------------
# Input Deutch sentence: es ist jetzt noch zu früh auf ein erfolgreiches engagement der usa im bereich des klimawandels zu zählen
# Actual English Translation:  it is too early to count on success in engaging the us on climate change
# Predicted English Translation:  it is too early to count on success in engaging
# -----------------------------------------
# Input Deutch sentence: gaza braucht händeringend knochenspezialisten doch gibt es die ausbildung dazu nur im ausland
# Actual English Translation:  gaza cries out for bone specialists but the training i need is available only abroad
# Predicted English Translation:  gaza cries out for bone specialists but the trai
# -----------------------------------------
# Input Deutch sentence: in der zwischenzeit gilt es allerdings wichtiges zu erledigen
# Actual English Translation:  in the meantime there is important work to be done
# Predicted English Translation:  in the meantime there is important work to be
# -----------------------------------------
# Input Deutch sentence: so oder so droht mit hoher wahrscheinlichkeit eine schwere finanzkrise
# Actual English Translation:  either way the threat of a profound financial crisis is high
# Predicted English Translation:  either way the threat of a profound financial cr
# -----------------------------------------
# Input Deutch sentence: nicht alles ist mit gewalt zu erreichen
# Actual English Translation:  force cannot accomplish everything
# Predicted English Translation:  force cannot accomplish everything
# -----------------------------------------
# Input Deutch sentence: große banken repräsentieren die höchste stufe der konzentrierten wirtschaftsmacht in den heutigen volkswirtschaften
# Actual English Translation:  big banks represent the ultimate in concentrated economic power in todays economies
# Predicted English Translation:  big banks represent the ultimate in concentrate
# -----------------------------------------
# Input Deutch sentence: am deutlichsten jedoch sind die auswirkungen des geplanten amerikanischen truppenabzuges in südkorea zu spüren
# Actual English Translation:  but the impact of americas planned troop withdrawals is felt most keenly in south korea
# Predicted English Translation:  but the impact of americas planned troop withdra
# -----------------------------------------
# Input Deutch sentence: eupräsident romani prodi hat einen vorschlag zur stärkung der exekutive der union vorgelegt
# Actual English Translation:  eu commission president romano prodi has proposed a scheme to strengthen the unions executive
# Predicted English Translation:  eu commission president romano prodi has propos
# -----------------------------------------
# Input Deutch sentence: nostalgie ist nicht mehr das was sie einmal war
# Actual English Translation:  nostalgia is not what it used to be
# Predicted English Translation:  nostalgia is not what it used to be
# -----------------------------------------
# Input Deutch sentence: die kunden der bank haben weiterhin einen starken anreiz ihre banken zu überwachen
# Actual English Translation:  depositors still have a strong incentive to monitor their banks
# Predicted English Translation:  depositors still have a strong incentive to mon
# -----------------------------------------
# Input Deutch sentence: im eigenen land kann merkel hoffen deren ernte einzufahren
# Actual English Translation:  at home merkel can hope to reap the rewards
# Predicted English Translation:  at home merkel can hope to reap the rewards
# -----------------------------------------
# Input Deutch sentence: der prozess der entdeckung eines neuen wachstumspfades hat begonnen
# Actual English Translation:  the process of discovering a new growth path has started
# Predicted English Translation:  the process of discovering a new growth path has sta
# -----------------------------------------
# Input Deutch sentence: da die eumitglieder bereits hohe steuerliche belastungen haben würden weitere steuererhöhungen die wachstumskräfte schwächen
# Actual English Translation:  as eu members already have large tax burdens further tax increases would weaken the forces of growth
# Predicted English Translation:  as eu members already have large tax burdens fur
# -----------------------------------------
# Input Deutch sentence: ihre hauptargumente erinnern an argumente die von jenen vorgebracht wurden die die kubanische revolution befürworteten
# Actual English Translation:  their main arguments are reminiscent the arguments put forward by those who backed the cuban revolution
# Predicted English Translation:  their main arguments are reminiscent the argum
# -----------------------------------------
# Input Deutch sentence: im gegenteil anhaltende auseinandersetzungen zogen oft unmittelbar weitere finanzhilfen nach sich
# Actual English Translation:  on the contrary continued conflict often led directly to more financial aid
# Predicted English Translation:  on the contrary the idea of democratic candidates w
# -----------------------------------------
# Input Deutch sentence: sogar die seit zyklisch steigende arbeitslosigkeit in deutschland wird leicht sinken von  auf  millionen
# Actual English Translation:  indeed even german unemployment which has been rising in cycles since  will decline slightly in  from  to  million
# Predicted English Translation:  indeed even german investment in the rich bank is increa
# -----------------------------------------
# Input Deutch sentence: nur gemeinsamer wohlstand kann dem planeten wirkliche sicherheit geben
# Actual English Translation:  only shared prosperity can truly make the planet secure
# Predicted English Translation:  only shared prosperity can truly make the planet se
# -----------------------------------------
# Input Deutch sentence: in wahrheit ist dies kein sozialismus sondern eine ausweitung des lange bestehenden wohlfahrtsstaatlichen handelns zugunsten der unternehmen
# Actual English Translation:  in truth this is not socialism but an extension of long standing corporate welfarism
# Predicted English Translation:  in truth this is not socialism but an extensio
# -----------------------------------------
# Input Deutch sentence: sie sind bezahlbar und würden letzten endes in jedem fall große reingewinne bringen
# Actual English Translation:  they are affordable and in each case would ultimately deliver large net benefits
# Predicted English Translation:  they are affordable and in each case would ultima
# -----------------------------------------
# Input Deutch sentence: beginnen wir damit warum der euro fallen muss
# Actual English Translation:  lets begin with why the euro needs to fall
# Predicted English Translation:  lets begin with why the euro needs to fall
# -----------------------------------------
# Input Deutch sentence: die gute nachricht für asien lautet dass die meisten währungsbehörden in der region die geldpolitik tatsächlich straffen
# Actual English Translation:  the good news for asia is that most of the regions monetary authorities are in fact tightening policy
# Predicted English Translation:  the good news for asia is that the us needs to
# -----------------------------------------
# Input Deutch sentence: die staatsausgaben übertrafen die föderalen einnahmen trotz der nach rapide steigenden deviseneinnahmen aus ölexporten
# Actual English Translation:  government expenditure exceeded federal revenue despite rapidly rising foreignexchange earnings from oil exports after
# Predicted English Translation:  government expenditure exceeded federal revenue des
# -----------------------------------------
# Input Deutch sentence: der euro war immer ein beträchtliches wagnis ein großes experiment
# Actual English Translation:  the euro was always a big gamble a grand experiment
# Predicted English Translation:  the euro was always a big gamble a grand experi
# -----------------------------------------
# Input Deutch sentence: etwa japanische soldaten dienen im und um den irak
# Actual English Translation:  approximately  japanese forces serve in and around iraq
# Predicted English Translation:  approximately japanese forces serve in and around
# -----------------------------------------
# [[['sweden', 'has', 'developed', 'legislation', 'that', 'minimizes', 'bureaucracy', 'for', 'companies', 'that', 'need', 'foreign', 'workers']], [['the', 'wayward', 'kuchma', 'is', 'far', 'more', 'deserving', 'of', 'europe', 'imposing', 'safeguards', 'to', 'ensure', 'his', 'good', 'behavior']], [['as', 'a', 'result', 'of', 'globalization', 'large', 'family', 'firms', 'could', 'increase', 'their', 'size', 'and', 'their', 'geographic', 'range']], [['what', 'do', 'they', 'have', 'that', 'other', 'candidates', 'dont', 'and', 'that', 'so', 'many', 'americans', 'seem', 'to', 'want']], [['a', 'healthy', 'older', 'person', 'may', 'well', 'appreciate', 'parttime', 'work', 'if', 'it', 'comes', 'with', 'flexibility']], [['george', 'w', 'bushs', 'disastrous', 'war', 'in', 'iraq', 'has', 'put', 'europe', 'in', 'a', 'bind']], [['but', 'the', 'same', 'criticism', 'can', 'be', 'directed', 'at', 'sarkozy']], [['but', 'imf', 'accounting', 'inhibits', 'the', 'use', 'of', 'these', 'funds', 'to', 'help', 'stabilize', 'an', 'economy', 'through', 'countercyclical', 'fiscal', 'spending']], [['furthermore', 'mubarak', 'was', 'old', 'and', 'sick', 'and', 'no', 'longer', 'enjoyed', 'the', 'trust', 'of', 'his', 'people']], [['in', 'hong', 'kong', 'exports', 'actually', 'contracted', 'by', 'in', 'september', 'the', 'first', 'yearonyear', 'decline', 'in', 'months']], [['unfortunately', 'that', 'is', 'no', 'surprise']], [['never', 'before', 'has', 'america', 'the', 'worlds', 'biggest', 'consumer', 'been', 'so', 'weak', 'for', 'so', 'long']], [['it', 'is', 'a', 'sad', 'fact', 'that', 'a', 'large', 'majority', 'of', 'voters', 'in', 'the', 'eu', 'are', 'against', 'turkish', 'membership']], [['carbonfree', 'hydroelectric', 'power', 'is', 'the', 'right', 'choice', 'as', 'subsaharan', 'africas', 'principal', 'source', 'of', 'energy']], [['others', 'estimate', 'a', 'lower', 'but', 'still', 'alarming', 'rate', 'of']], [['nothing', 'could', 'be', 'more', 'incorrect']], [['in', 'the', 'past', 'two', 'decades', 'governments', 'have', 'come', 'up', 'short', 'on', 'solutions', 'to', 'environmental', 'threats']], [['perhaps', 'if', 'both', 'wings', 'had', 'united', 'that', 'single', 'party', 'would', 'have', 'appeared', 'as', 'an', 'unbeatable', 'juggernaut']], [['subsidies', 'and', 'trade', 'barriers']], [['indeed', 'to', 'expect', 'such', 'results', 'by', 'the', 'proposed', 'fourmonth', 'deadline', 'is', 'highly', 'implausible']], [['yet', 'ten', 'years', 'later', 'the', 'same', 'signor', 'cavallo', 'is', 'trying', 'to', 'fend', 'off', 'recession', 'and', 'government', 'default']], [['the', 'current', 'aid', 'structures', 'are', 'inadequate']], [['the', 'worlds', 'population', 'has', 'tripled', 'since', 'the', 'united', 'nations', 'was', 'created', 'in']], [['but', 'a', 'revival', 'of', 'economic', 'growth', 'in', 'the', 'short', 'term', 'is', 'unlikely']], [['for', 'the', 'eurozones', 'southern', 'periphery', 'however', 'todays', 'euro', 'rate', 'is', 'very', 'difficult', 'to', 'manage']], [['president', 'barack', 'obama', 'has', 'deployed', 'the', 'confidence', 'multiplier', 'and', 'claims', 'to', 'have', 'contained', 'the', 'recession']], [['it', 'is', 'too', 'early', 'to', 'count', 'on', 'success', 'in', 'engaging', 'the', 'us', 'on', 'climate', 'change']], [['gaza', 'cries', 'out', 'for', 'bone', 'specialists', 'but', 'the', 'training', 'i', 'need', 'is', 'available', 'only', 'abroad']], [['in', 'the', 'meantime', 'there', 'is', 'important', 'work', 'to', 'be', 'done']], [['either', 'way', 'the', 'threat', 'of', 'a', 'profound', 'financial', 'crisis', 'is', 'high']], [['force', 'cannot', 'accomplish', 'everything']], [['big', 'banks', 'represent', 'the', 'ultimate', 'in', 'concentrated', 'economic', 'power', 'in', 'todays', 'economies']], [['but', 'the', 'impact', 'of', 'americas', 'planned', 'troop', 'withdrawals', 'is', 'felt', 'most', 'keenly', 'in', 'south', 'korea']], [['eu', 'commission', 'president', 'romano', 'prodi', 'has', 'proposed', 'a', 'scheme', 'to', ...
# [['sweden', 'has', 'developed', 'legislation', 'that', 'minimizes', 'bureauc'], ['the', 'wayward', 'kuchma', 'is', 'far', 'more', 'deserving', 'of', 'eu'], ['as', 'a', 'result', 'of', 'globalization', 'large', 'family', 'firms', 'c'], ['what', 'do', 'they', 'have', 'that', 'many', 'candidates', 'dont', 'wan'], ['a', 'healthy', 'older', 'person', 'may', 'well', 'appreciate', 'part'], ['george', 'w', 'bushs', 'disastrous', 'war', 'in', 'iraq', 'has', 'put', 'eu'], ['but', 'the', 'same', 'criticism', 'can', 'be', 'directed', 'at', 'sarkozy'], ['but', 'imf', 'accounting', 'inhibits', 'the', 'use', 'of', 'these', 'f'], ['furthermore', 'mubarak', 'was', 'old', 'and', 'sick', 'and', 'no', 'lo'], ['in', 'hong', 'kong', 'exports', 'actually', 'contracted', 'by', 'in', 'septe'], ['unfortunately', 'that', 'is', 'no', 'surprise'], ['never', 'before', 'has', 'the', 'worlds', 'biggest', 'consumer', 'bee'], ['it', 'is', 'a', 'sad', 'fact', 'that', 'a', 'large', 'majority', 'of', 'the', 'f'], ['carbonfree', 'hydroelectric', 'power', 'is', 'the', 'right', 'ch'], ['others', 'estimate', 'a', 'lower', 'but', 'still', 'alarming', 'rat'], ['nothing', 'could', 'be', 'more', 'incorrect'], ['in', 'the', 'past', 'two', 'decades', 'governments', 'have', 'come', 'up', 's'], ['perhaps', 'if', 'both', 'wings', 'had', 'united', 'that', 'single', 'p'], ['subsidies', 'and', 'trade', 'barriers'], ['indeed', 'to', 'expect', 'such', 'results', 'by', 'the', 'proposed', 'fourm'], ['yet', 'ten', 'years', 'later', 'the', 'same', 'signor', 'cavallo', 'is', 'tr'], ['the', 'current', 'aid', 'structures', 'are', 'inadequate'], ['the', 'worlds', 'population', 'has', 'tripled', 'since', 'the', 'un'], ['but', 'a', 'few', 'time', 'at', 'least', 'this', 'is', 'different', 'for', 'amer'], ['for', 'the', 'eurozones', 'southern', 'periphery', 'however', 'to'], ['president', 'barack', 'obama', 'has', 'deployed', 'the', 'confid'], ['it', 'is', 'too', 'early', 'to', 'count', 'on', 'success', 'in', 'engaging'], ['gaza', 'cries', 'out', 'for', 'bone', 'specialists', 'but', 'the', 'trai'], ['in', 'the', 'meantime', 'there', 'is', 'important', 'work', 'to', 'be'], ['either', 'way', 'the', 'threat', 'of', 'a', 'profound', 'financial', 'cr'], ['force', 'cannot', 'accomplish', 'everything'], ['big', 'banks', 'represent', 'the', 'ultimate', 'in', 'concentrate'], ['but', 'the', 'impact', 'of', 'americas', 'planned', 'troop', 'withdra'], ['eu', 'commission', 'president', 'romano', 'prodi', 'has', 'propos'], ['nostalgia', 'is', 'not', 'what', 'it', 'used', 'to', 'be'], ['depositors', 'still', 'have', 'a', 'strong', 'incentive', 'to', 'mon'], ['at', 'home', 'merkel', 'can', 'hope', 'to', 'reap', 'the', 'rewards'], ['the', 'process', 'of', 'discovering', 'a', 'new', 'growth', 'path', 'has', 'sta'], ['as', 'eu', 'members', 'already', 'have', 'large', 'tax', 'burdens', 'fur'], ['their', 'main', 'arguments', 'are', 'reminiscent', 'the', 'argum'], ['on', 'the', 'contrary', 'the', 'idea', 'of', 'democratic', 'candidates', 'w'], ['indeed', 'even', 'german', 'investment', 'in', 'the', 'rich', 'bank', 'is', 'increa'], ['only', 'shared', 'prosperity', 'can', 'truly', 'make', 'the', 'planet', 'se'], ['in', 'truth', 'this', 'is', 'not', 'socialism', 'but', 'an', 'extensio'], ['they', 'are', 'affordable', 'and', 'in', 'each', 'case', 'would', 'ultima'], ['lets', 'begin', 'with', 'why', 'the', 'euro', 'needs', 'to', 'fall'], ['the', 'good', 'news', 'for', 'asia', 'is', 'that', 'the', 'us', 'needs', 'to'], ['government', 'expenditure', 'exceeded', 'federal', 'revenue', 'des'], ['the', 'euro', 'was', 'always', 'a', 'big', 'gamble', 'a', 'grand', 'experi'], ['approximately', 'japanese', 'forces', 'serve', 'in', 'and', 'around']]

# %%
score = corpus_bleu(ref, can)
print("BLEU Score LSTM : ", score)
# Out:
# BLEU Score LSTM :  0.49060869112990874

# %% [markdown]
# ## MODEL EVALUATION

# %%
batch_size = 1

# %%
val_gen = generate_batch(X_test, y_test)

# %%
ref = []
can = []

for k in range(len(X_test)):
    (input_seq, actual_output), _ = next(val_gen)
#     print(input_seq)
#     print(np.shape(input_seq))
#     print(actual_output)
#     print(np.shape(actual_output))
#     print(_)
    decoded_sentence = decode_sequence(input_seq)
    print('Input Deutsch sentence:', X_test[k:k+1].values[0])
    print('Actual English Translation:', y_test[k:k+1].values[0][6:-4])
    ref.append([y_test[k:k+1].values[0][6:-4].split()])
    print('Predicted English Translation:', decoded_sentence[:-4])
    can.append(decoded_sentence[:-4].split())
    print("---------------------------------------------------------------------------------")
# Out:
# Input Deutsch sentence: greenspan bekennt sich zudem schuldig den character der bushregierung falsch eingeschätzt zu haben
# Actual English Translation:  greenspan also pleads guilty to misunderstanding the character of the bush administration
# Predicted English Translation:  greenspan also pleads guilty to misunderstanding
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: und das bei einer krise wie sie in einem halben jahrhundert nur einmal vorkommt
# Actual English Translation:  and the crisis was a onceinahalfcentury event
# Predicted English Translation:  however he is now and the most of such as an impo
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: japans langsames wachstum und niedrige zinsen während der letzten beiden jahrzehnte sind hier beispielhaft
# Actual English Translation:  japans slow growth and low interest rates over the past two decades are emblematic
# Predicted English Translation:  japans slow growth and low interest rates over
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: sicher alle drei währungen haben ihre kritiker
# Actual English Translation:  to be sure all three currencies have their critics
# Predicted English Translation:  to be sure all the united states continued its
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: nach dem  september änderte sich das rasch
# Actual English Translation:  this rapidly changed after last september th
# Predicted English Translation:  this rapidly changed after last september th
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ich habe sechs brüder und drei schwestern
# Actual English Translation:  i have six brothers and three sisters
# Predicted English Translation:  i have six brothers and three sisters
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: selbst in vielen entwickelten ländern wird noch immer ein großteil des stroms aus kohle erzeugt
# Actual English Translation:  even in many developed countries coal still accounts for a large share of power generation
# Predicted English Translation:  even in many years has over major investment in w
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die verfügbarkeit von medikamenten ist heute aufgrund zweier hauptprobleme eingeschränkt
# Actual English Translation:  two main problems limit the availability of medicines today
# Predicted English Translation:  two main problems limit the availability of medic
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: hat es eine neue positive politische kraft geboren die reformen beschleunigen wird
# Actual English Translation:  has the quake given birth to some new positive political force that will accelerate reform
# Predicted English Translation:  has the quake given birth to a new political argu
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das funktionierte auch aber auf grundsätzlich andere art als geldpolitik normalerweise funktioniert
# Actual English Translation:  it worked but in a way fundamentally different from how monetary policy normally works
# Predicted English Translation:  it worked to see the un or even worse from for
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diese botschaft ist eine schlechte nachricht für die amerikanische diplomatie
# Actual English Translation:  that message is bad news for american diplomacy
# Predicted English Translation:  that message is bad news for american diplomacy
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: doch sind für derartige maßnahmen keine anzeichen zu erkennen
# Actual English Translation:  but we are not seeing signs of anything like this
# Predicted English Translation:  but we are not just that argentina will do so
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: arafat hat einer machtaufteilung nie wirklich zugestimmt
# Actual English Translation:  arafat never really agreed to share power
# Predicted English Translation:  arafat never really agreed to share power
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wir nähern uns einem punkt an dem die verfassungsmäßige maßgabe universeller kostenloser bildung zur fiktion werden könnte
# Actual English Translation:  we have approached the point when the constitutional requirement of universal free education may become a fiction
# Predicted English Translation:  we have approached the point in our speech as a disappoint
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: rumsfeld behauptete die aussage bushs sei technisch korrekt
# Actual English Translation:  rumsfeld said that bushs statement was technically accurate
# Predicted English Translation:  rumsfeld said that bushs statement was technic
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: perverse subventionen müssen abgeschafft und solche die produkte wie biokraftstoffe bevorzugen überdacht werden
# Actual English Translation:  perverse subsidies must be removed and recent new ones favoring products such as biofuels reconsidered
# Predicted English Translation:  perverse subsidies must be removed and on argent
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die beweise für eine vertrauenskrise sind eher schwierig zu interpretieren
# Actual English Translation:  in fact the evidence for a crisis of trust is rather difficult to interpret
# Predicted English Translation:  in fact the us and a country of any western gam
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die erfahrung in kalifornien ist ein beispiel
# Actual English Translation:  the california experience is a case in point
# Predicted English Translation:  the answer is a choice in why
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: und nun läuft man gefahr einen weiteren wichtigen ansatz zu übersehen
# Actual English Translation:  and now it risks missing another important clue
# Predicted English Translation:  and now it risks missing another important clue
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die ausgabefreudigkeit erhöhte sich kaum
# Actual English Translation:  very little was added to current spending
# Predicted English Translation:  so where it has been
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die gap wurde binnen kurzem als edelstein in der krone des europäischen projekts betrachtet
# Actual English Translation:  the cap quickly came to be seen as the jewel in the crown of the european project
# Predicted English Translation:  the cap would be applied in a series of a man and
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: stattdessen ist es ausländischen presseorganisationen zugefallen ihn zu verteidigen
# Actual English Translation:  instead it has fallen to foreign press organizations to defend him
# Predicted English Translation:  instead it has to join a interests of russias inter
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die griechische erfahrung wirkt zumindest bisher wie eine neuaufführung des argentinischen dramas
# Actual English Translation:  the greek experience so far at least looks like a replay of the argentine drama
# Predicted English Translation:  the greek experience so far at least looks like a re
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: anders ausgedrückt führt frankreich zwar aber nicht immer auf konstruktive weise
# Actual English Translation:  in other words even when france leads it does not always do so in a constructive way
# Predicted English Translation:  in other words even when they had been unable to
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: natürlich gibt es keinen perfekten buchungsrahmen aber einige solcher rahmen verzerren planmäßig
# Actual English Translation:  of course no perfect accounting framework exists but some frameworks systematically distort
# Predicted English Translation:  of course no perfect accounting framework exists
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wie formt ihr gehirn die für sie bedeutendsten erinnerungen
# Actual English Translation:  how does your brain form its most significant memories
# Predicted English Translation:  and it is also had the police with oil
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: sie bezichtigt krieger sie seien händler und händler sie seien diebe und meidet zugleich ihre marxistischen ursprünge
# Actual English Translation:  accusing warriors of being traders and traders of being thieves it shuns its marxist origins
# Predicted English Translation:  accusing warriors of being traders and traders of b
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wenn die europäischen staats und regierungschefs tatsächlich planen sich in sarajevo zu treffen sollten sie jetzt handeln
# Actual English Translation:  if european leaders do plan to meet in in sarajevo they should act now
# Predicted English Translation:  if european leaders do plan to meet in such legiti
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: selbstverständlich trägt israel die verantwortung dafür sowohl schlechte politik gemacht als auch politische sünden begangen zu haben
# Actual English Translation:  of course israel has been guilty of both bad policies and political sins
# Predicted English Translation:  of course has already been far as with much whil
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: bei einer derart intensiven nutzung des grundstücks ist die gefahr einer grundstücksknappheit  verschwindend gering
# Actual English Translation:  with such intensive use of land our land constraints for housing construction are vanishingly small
# Predicted English Translation:  as a few years ago i still typically had become a
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die privaten gewinne kann am besten an der bezahlung von führungskräften erkennen
# Actual English Translation:  the private gains can be measured most directly in the form of executive compensation
# Predicted English Translation:  the private gains can be measured because the da
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: es ist müßig zu erwähnen dass es derartige probleme in vielen der rasch wachsenden ökonomien asiens nicht gibt
# Actual English Translation:  needless to say there are no such hangups in many of the highgrowth economies of asia
# Predicted English Translation:  needless to say there are no substantial hangup
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: aber der springende punkt ist folgender jetzt ist nicht der moment das handeln aufzuschieben
# Actual English Translation:  but the point is now is not the time to put off action
# Predicted English Translation:  but the not issue the country is not used on the
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: tatsächlich haben sie so sehr recht dass sie wieder unrecht haben
# Actual English Translation:  in fact they are so right that they are wrong
# Predicted English Translation:  in fact they are so right that they are wrong
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das gleiche gilt auch für demokratie
# Actual English Translation:  the same is true of democracy
# Predicted English Translation:  the same is true of democracy
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: kritiker der bilanz der usa als globaler hegemonialmacht liefern überzeugende argumente gegen eine unipolare welt
# Actual English Translation:  critics of americas record as a global hegemony make a strong case against a unipolar world
# Predicted English Translation:  critics of americas record as a global hegemony
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ich fürchte das palästinensische volk wird noch nach seinem tod darunter leiden
# Actual English Translation:  i am afraid the palestinian people will still be suffering from it even after his death
# Predicted English Translation:  i have a child and corporate man who did only his
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das bedeutet einen verzicht auf manche staatliche leistung
# Actual English Translation:  that means forgoing some government services
# Predicted English Translation:  that means forgoing some government services
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das trifft auch hundertprozentig zu
# Actual English Translation:  all this is perfectly true
# Predicted English Translation:  all this is perfectly true
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die juden so die behauptung der verteidigung sind keine eigene rasse
# Actual English Translation:  the jews the defense claimed do not constitute a race
# Predicted English Translation:  the jews the public consequences would not two dec
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: politiker können dieses so genannte rentseekingverhalten die suche nach staatlich geschützten machtpositionen nicht stoppen
# Actual English Translation:  politicians cant stop such rentseeking behavior
# Predicted English Translation:  politicians cant stop such rentseeking behavior
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dieses defizit spiegelt ein grundlegendes forschungsdefizit wider
# Actual English Translation:  this deficit reflects an underlying research deficit
# Predicted English Translation:  this deficit reflects an underlying research def
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: aber die amerikaner auf der anderen seite des atlantiks haben auch keinen grund für selbstgefälligkeit
# Actual English Translation:  but on the other side of the atlantic americans have no reason to feel smug
# Predicted English Translation:  but on the prospect of military institutions is
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: sie unterstützen die äthiopische armee in somalia
# Actual English Translation:  it backs the ethiopian army in somalia
# Predicted English Translation:  it backs the ethiopian army in somalia
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dieser gründet sich überwiegend auf die weit verbreitete wahrnehmung der usa als arrogant
# Actual English Translation:  this is largely due to a widespread perception of american arrogance
# Predicted English Translation:  this is largely due to a sustainable economic disa
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: kutschma weiß daher dass er sich nicht wie jelzin einen handverlesenen nachfolger aussuchen kann
# Actual English Translation:  so kuchma knows that he cannot rely on handpicking his successor as yeltsin did in russia
# Predicted English Translation:  no one is not viewed as the west that in arafat
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: jetzt haben wir endlich eine chance aus der abwärtsspirale eines ökonomischen niedergangs auszubrechen
# Actual English Translation:  now we finally have a chance to break out of the downward spiral of economic decline
# Predicted English Translation:  should it however the idea of the most part of
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: es ist sinnvoll zunächst in bereiche zu investieren wo der größte nutzen erzielt werden kann
# Actual English Translation:  it makes sense to first invest in the areas that achieve the greatest benefits
# Predicted English Translation:  it is a impact when that will be in place in the afr
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: im gegensatz dazu gerät das regime selbst in gefahr wenn es an seinen engen grundlagen festhält
# Actual English Translation:  by contrast the regime itself will be imperiled if it clings to its narrow base
# Predicted English Translation:  by contrast the regime itself will be imperile
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dadurch sind sie für die industrie eine echte herausforderung obwohl sie nach und nach in anwendungen verwendet werden
# Actual English Translation:  as such they are a challenge for industry though applications are beginning to appear
# Predicted English Translation:  it would lead to our growth of how private help
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: asiatische länder verfolgen mit zunehmender nervosität wie die demokraten eine neuverhandlung der nafta vorschlagen
# Actual English Translation:  as democrats suggest renegotiating nafta asian countries are watching with increasing trepidation
# Predicted English Translation:  as democrats suggest renegotiating nafta asian count
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: und sie glauben also das war ein schlechtes jahr
# Actual English Translation:  so you thought this year was bad
# Predicted English Translation:  who is still an third and that that was a break
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ebenso wenig sehen sie eine landreform arbeitsvermittlung oder rentenansprüche für alle asiaten als priorität an
# Actual English Translation:  nor do they consider land reform employment services or pensions for all asians a priority
# Predicted English Translation:  nor do they do our even back with those who had
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: sollte uns irgendetwas davon abhalten anpassungsstrategien zu nutzen
# Actual English Translation:  should any of this stop us from using adaptation strategies
# Predicted English Translation:  should this of us up to be defined by adaptation
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wir wissen dass amerikas gesundheitssystem trotz des großen reichtums des landes und seiner bahnbrechenden medizinischen forschung erbärmlich ist
# Actual English Translation:  we know that despite its great wealth and its groundbreaking medical research americas healthcare system is awful
# Predicted English Translation:  we know that despite its great wealth and its groundbrea
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: muss jede form einer rassenbezogenen sprachlichen äußerung die jemanden beleidigen könnte verfolgt werden
# Actual English Translation:  is any form of racerelated speech that anybody finds offensive to be prosecuted
# Predicted English Translation:  one party has taken seriously even as it is not shrin
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: amerika ist stark und die weltwirtschaft ist es
# Actual English Translation:  america is strong and the global economy is strong
# Predicted English Translation:  america is where the world needs to avoid america
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: es wird wieder einmal der europäischen union obliegen dazu beizutragen dass sich verzweifelung in hoffnung verwandelt
# Actual English Translation:  it will fall to the union once again to help transform despair into hope
# Predicted English Translation:  it will fall to the end that once it reaches th
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dies würde allen volkswirtschaften helfen
# Actual English Translation:  this would help all economies
# Predicted English Translation:  this can be achieved as
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: lag das verhältnis der hypotheken und verbraucherschulden zum bip bei über   gegenüber nettoauslandsschulden von
# Actual English Translation:  in  the mortgage and consumer debttogdp ratio was more than  compared to  for net foreign debt
# Predicted English Translation:  in the mortgage and consumer debttogdp ratio was
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: keiner von ihnen wurde je vor gericht gestellt
# Actual English Translation:  none of them has ever been put on trial
# Predicted English Translation:  none of them has been devoted to a free process
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: unter den heutigen polarisierenden umständen wird die suche nach einem neuen palästinenserchef wahrscheinlich jahre dauern
# Actual English Translation:  in todays divisive circumstances the emergence of a new palestinian leader will most likely take years
# Predicted English Translation:  in todays divisive circumstances the problem o
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: und ein solcher plan ist nicht nur fair sondern bietet zugleich praktische vorteile
# Actual English Translation:  but in addition to being fair this scheme also has practical benefits
# Predicted English Translation:  but in addition to being fair this scheme is not pract
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die rechtliche grundlage des usdrohnenprogramms jedoch ist völlig unklar
# Actual English Translation:  the us drone programs legal basis is entirely unclear however
# Predicted English Translation:  the us drone programs legal basis is entirely unc
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diese sachlage stellt ein versagen von wirtschaft und recht dar das dringend korrigiert werden muss
# Actual English Translation:  this state of affairs represents a failure of economics and law that urgently needs to be corrected
# Predicted English Translation:  this approach requires a mistake of israels destruc
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ist das der untergang der entwicklungsländer
# Actual English Translation:  will this spell doom for developing countries
# Predicted English Translation:  will this spell doom for developing countries
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: langfristig sollte die budgetkonsolidierung durchaus eine voraussetzung für die hilfeleistung internationaler organisationen sein
# Actual English Translation:  fiscal consolidation should be a condition for the longerterm aid that international organizations will have to provide
# Predicted English Translation:  fiscal consolidation should be a condition for
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: zudem trägt die ezb de facto bereits verantwortung für die stabilität des bankensystems innerhalb der eurozone
# Actual English Translation:  moreover the ecb already bears de facto responsibility for the stability of the eurozones banking system
# Predicted English Translation:  moreover the ecb already bears de facto responsibi
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: nigeria ist das musterbeispiel dafür wie konzerne ungestraft die umwelt schädigen
# Actual English Translation:  nigeria has been exhibit a of corporate environmental impunity
# Predicted English Translation:  nigeria has been exhibit a global externality o
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: der rückgang der gewalt gilt für familien nachbarschaften sippen und staaten
# Actual English Translation:  the decline in violence holds for families neighborhoods tribes and states
# Predicted English Translation:  the decline in us increased increased by the chil
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wie wäre es damit eine ihrer nächsten alle zwei monate stattfindenden sitzungen in simbabwe auszurichten wo hyperinflation herrscht
# Actual English Translation:  how about holding one of their bimonthly meetings in hyperinflationary zimbabwe
# Predicted English Translation:  how to least a texas open at least their resou
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: in dieser welt ohne utopien ist die freiheit des individuums das höchste wertgut
# Actual English Translation:  in this world without utopia individual freedom is the supreme value
# Predicted English Translation:  in the global side global powers that iran is its guara
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: länder haben anders als menschen keine vorhersehbare lebensspanne
# Actual English Translation:  countries are not like humans with predictable life spans
# Predicted English Translation:  countries are not like humans with predictable
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: was erklärt dieses sonderbare verhalten
# Actual English Translation:  what explains this odd behavior
# Predicted English Translation:  what explains this odd behavior
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diese fragen sind von zentraler bedeutung
# Actual English Translation:  these are weighty questions
# Predicted English Translation:  these are careful preparation policies
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: eine weitere party hier wird die britische regierung nicht tolerieren
# Actual English Translation:  the british government will not tolerate another jamboree
# Predicted English Translation:  some arrived that too things have a big way to a quag
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: sie hat jedoch ihren preis
# Actual English Translation:  but it cannot be had for nothing
# Predicted English Translation:  but it cannot be by
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ebenso entscheiden sich länder oft auch nicht zu kooperieren
# Actual English Translation:  similarly countries often choose not to cooperate
# Predicted English Translation:  similarly countries often choose not to cooperate
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die große depression wurde durch handelsbarrieren verschärft die länder zum schutz ihrer heimischen beschäftigten verhängten
# Actual English Translation:  the great depression was aggravated by the trade barriers that countries imposed to protect domestic employment
# Predicted English Translation:  the need for financial market nations have acce
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: an der politischen front gibt es ebenfalls grund zur unruhe
# Actual English Translation:  the policy front will be equally unsettling
# Predicted English Translation:  the most two decades will be asked in
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: der klimawandel ist zu wichtig um ihn den politikern zu überlassen
# Actual English Translation:  the climate change issue is too important to be left in the care of politicians
# Predicted English Translation:  the climate change issue is too important to b
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die profite der drogenhändler am anderen ende der kette werden fast mal so hoch liegen
# Actual English Translation:  profits for drug traffickers downstream will be almost times that amount
# Predicted English Translation:  profits for drug traffickers downstream will be
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: keiner von ihnen hat daher einen grund unbehagen über die türkei zu äußern
# Actual English Translation:  none of them therefore has any reason to express discomfort with turkey
# Predicted English Translation:  none of them is an matter of national human ri
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die manager haben zwar ihre arbeitsplätze verloren und müssen nun auf ihren anspruch auf zusätzliche entschädigungen verzichten
# Actual English Translation:  to be sure the executives lost their jobs and now must drop claims for additional compensation
# Predicted English Translation:  to be sure the efsfs interest as the favorite of
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die initiative der asean ist für die vereinigung ein neuartiger schritt vorwärts
# Actual English Translation:  aseans initiative is a new step forward for the group
# Predicted English Translation:  aseans initiative is a new step forward for the
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dies ist der wahre europäische geist und keine zweifel können ihn brechen
# Actual English Translation:  that is the true european spirit and no doubts can crush it
# Predicted English Translation:  that is the true european spirit and no doubts
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: hier beging der iwf einen fatalen fehler indem er eine kontraktionäre finanzpolitik unterstützte
# Actual English Translation:  here the imf made its fatal mistake
# Predicted English Translation:  here the imf made its fatal mistake
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die vorgeschlagene entsendung von zusätzlichen  marineinfanteristen in australien ist größtenteils symbolischer natur
# Actual English Translation:  the proposed deployment of an additional  marines in australia is largely symbolic
# Predicted English Translation:  to the top people will be on them by
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: man muss herumtelefonieren und die staats und regierungschefs der welt dazu überreden dieses oder jenes zu tun
# Actual English Translation:  you have to work the phones cajole world leaders to do this or that
# Predicted English Translation:  you have to see the same and what they could do
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: momentan beherrscht der usdollar die szene
# Actual English Translation:  currently the us dollar remains dominant
# Predicted English Translation:  currently the us dollar remains dominant
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: jeder uspräsident ernennt tausende beamte wovon viele mit beträchtlichen machtbefugnissen ausgestattet sind
# Actual English Translation:  every us president appoints thousands of officials many with considerable power
# Predicted English Translation:  every us president appoints thousands of offic
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die nettosparquote fiel beinahe auf null
# Actual English Translation:  the net saving rate fell to near zero
# Predicted English Translation:  the other trade rate of free of land which is
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: somit war der  september direkt oder indirekt ein großer schock sowohl psychologisch als auch für unsere politischen systeme
# Actual English Translation:  thus  has meant directly or indirectly a great shock both psychologically and to our political systems
# Predicted English Translation:  thus has meant have caught even better as an rep
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dabei werden die politiker schließlich so etwas wie eine allgemeine öffentliche unterstützung finden
# Actual English Translation:  in this politicians will at last have something like united public support
# Predicted English Translation:  in many politicians may be more stable country
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: eine geteilte regierungsgewalt spielt auch in die hände asiatischer separatisten
# Actual English Translation:  divided government also plays into the hands of asias separatists
# Predicted English Translation:  divided government also plays into the hands of a
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dies war im buchstäblichen sinne wahr denn die briten hatten so etwas berichtet
# Actual English Translation:  this was literally true because the british had reported that
# Predicted English Translation:  this was literally true because the british was repo
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: um das zu beantworten müssen wir natürlich entscheiden was diese rechte sind
# Actual English Translation:  to answer that of course we need to decide what those rights are
# Predicted English Translation:  to answer that of course the ground are not en
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die schaffung des sustainable development solutions network durch den generalsekretär ist daher besonders zeitgemäß
# Actual English Translation:  the secretary generals launch of the sustainable development solutions network is therefore especially timely
# Predicted English Translation:  the secretary generals launch of the various reces
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: seine argumente klingen vernünftig
# Actual English Translation:  his arguments sound reasonable
# Predicted English Translation:  his arguments sound reasonable
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: man stelle sich vor was passiert wenn ebenso viele myanmarische wie pakistanische generäle amerika besuchen
# Actual English Translation:  imagine the impact if as many myanmar generals visited america as pakistani generals do
# Predicted English Translation:  imagine the issue in serbia can free and fair re
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die probleme der amerikanischen wirtschaft und des finanzsystems waren jahrelang offensichtlich
# Actual English Translation:  the problems in the us economy and financial system have been apparent for years
# Predicted English Translation:  the the household sector and the two economy will
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die niederländer waren immer stolz darauf das toleranteste volk der erde zu sein
# Actual English Translation:  the dutch always took pride in being the most tolerant people on earth
# Predicted English Translation:  the dutch always took pride in the ndr secured to s
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: warum hat er sich verschärft
# Actual English Translation:  why did it worsen
# Predicted English Translation:  why did it worsen
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: in irland war die situation zunächst nicht viel anders
# Actual English Translation:  in the case of ireland the situation was initially not much different
# Predicted English Translation:  in the world two decades has been part of this appr
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ihre ergebnisse sind faszinierend
# Actual English Translation:  their conclusions are fascinating
# Predicted English Translation:  their conclusions are fascinating
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wie nicht anders zu erwarten wurde dieser region weltweit respekt gezollt
# Actual English Translation:  not surprisingly this region was globally respected
# Predicted English Translation:  not surprisingly this region was globally respe
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das soll ein triumph sein
# Actual English Translation:  thats a triumph
# Predicted English Translation:  thats a triumph
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: wird sich diese sehnsucht über den nil hinaus ausbreiten wie sie es schon von tunis nach kairo tat
# Actual English Translation:  will this yearning travel beyond the nile as it did from tunis to cairo
# Predicted English Translation:  will this yearning travel beyond the nile as it
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: amerika hatte eine moralische verantwortung die jungen menschen zu schützen die von obama ermutigt worden waren
# Actual English Translation:  america had a moral responsibility to protect the young people whom obama had encouraged
# Predicted English Translation:  america had a broad case a leading place with the s
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: loderte der grenzkonflikt wieder auf
# Actual English Translation:  more recently in  the border issue flared again
# Predicted English Translation:  more recently in the worlds soviet union had up
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: stattdessen erhaschen sie mit der hilfe amerikas einen ersten blick auf die freiheit
# Actual English Translation:  instead with americas help they are enjoying the first blush of freedom
# Predicted English Translation:  instead they have never been in fact with those
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: blairs euroskeptizismus ist insofern verständlich als er mit der britischen befindlichkeit übereinstimmt
# Actual English Translation:  blairs euroskepticism is understandable insofar as it chimes with the british mood
# Predicted English Translation:  blairs euroskepticism is understandable insofa
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: obwohl es schwer fällt diese veränderung präzise zu fassen heißt das nicht dass sie deshalb unwichtig sind
# Actual English Translation:  while these changes are difficult to think about with any degree of precision that doesnt make them unimportant
# Predicted English Translation:  while these changes are difficult to think that politic
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diese verführung hat es amerika ermöglich fast zwei jahrzehnte lang über seine verhältnisse zu leben
# Actual English Translation:  that seduction has encouraged america to squander its savings and live beyond its means for nearly two decades
# Predicted English Translation:  that seduction has encouraged us since its carbon emiss
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: und trotz allem stagnieren die beschäftigungszahlen unter dem strich werden in den usa weiterhin keine neuen arbeitsplätze geschaffen
# Actual English Translation:  yet despite all this employment remained stagnant net job creation in the united states continues to stall
# Predicted English Translation:  yet despite all this demand of natural generation
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: paris ist tunesien nur der erste autoritäre arabische dominostein der fällt
# Actual English Translation:  paris is tunisia the first arab authoritarian domino to fall
# Predicted English Translation:  paris is tunisia the idea of an economic allianc
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: es ist eine gemeinschaft von menschen
# Actual English Translation:  it is a community of human beings
# Predicted English Translation:  it is a profound moment of human beings
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: eine neue währung wurde eingeführt und mit einem festen wechselkurs im verhältnis  an den dollar gekoppelt
# Actual English Translation:  a new currency was introduced and pegged to the us dollar at a onetoone exchange rate
# Predicted English Translation:  a new currency was introduced and pegged to th
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: mit der zeit müssten die länder der eurozone zwangsläufig den großteil der griechischen staatsschulden refinanzieren
# Actual English Translation:  over time the eurozone countries would inevitably have to refinance most of greeces public debt
# Predicted English Translation:  over time the eurozone countries would have to
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: aber was für gemeinsame werte teilen könig papst und amerikanischer präsident
# Actual English Translation:  but what common values do king pope and american president share
# Predicted English Translation:  but what is an traditional and advantage for its
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: aber natürlich hatte meine großmutter recht die niederlage mit befreiung gleichzusetzen
# Actual English Translation:  but of course my grandmother was right to equate defeat with liberation
# Predicted English Translation:  but of course my grandmother was right to equate de
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die botschaft an den kreml wäre glasklar macht euch nichts vor
# Actual English Translation:  the message to the kremlin here would be crystal clear
# Predicted English Translation:  the message to the kremlin here would be crystal c
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dieses ereignis führte zu einer massiven reaktion chinas wo studenten gegen diesen besuch demonstrierten
# Actual English Translation:  the decision triggered a severe response from china where students held demonstrations against his visit
# Predicted English Translation:  the decision triggered a severe response from c
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diese länder zu nachhaltigem wachstum zurückzuführen kann nicht durch weitere solche ausgaben erreicht werden
# Actual English Translation:  more such spending will not return these countries to a sustainable growth path
# Predicted English Translation:  all such countries will have been made to save amer
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: sie wollen keinen waffenstillstand mit der zivilisierten welt
# Actual English Translation:  they do not seek an armistice with the civilized world
# Predicted English Translation:  they will not want to the international market
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: der gegensatz zu afrikas schulden könnte krasser kaum sein
# Actual English Translation:  the contrast with africas debts could hardly be starker
# Predicted English Translation:  the contrast with africas debts could hardly be sta
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: im september einigten sich die mitgliedsstaaten der vereinten nationen auf die millenniumentwicklungsziele
# Actual English Translation:  the united nations member states adopted the millennium development goals in september
# Predicted English Translation:  the united nations member states has grown by
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: zugegeben manchmal ist zeit ein luxus
# Actual English Translation:  admittedly sometimes time is a luxury
# Predicted English Translation:  admittedly sometimes time is a luxury
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: mit der deregulierung kam es zu wettbewerb und reduzierten margen
# Actual English Translation:  deregulation meant competition and thinner margins
# Predicted English Translation:  deregulation meant competition and thinner mar
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: stattdessen scheint die bushadministration entschlossen genau das gegenteil zu tun
# Actual English Translation:  instead the bush administration seems intent on doing just the opposite
# Predicted English Translation:  instead the bush administration seems intent on
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: im jahr können wir damit beginnen einen neuen weg einzuschlagen
# Actual English Translation:  in  we can begin to change direction
# Predicted English Translation:  in we can begin to change at the union
# ---------------------------------------------------------------------------------
# ...
# Input Deutsch sentence: doch der rasante aufstieg der taliban in den ern war untrennbar mit dem versagen der bewässerungssysteme verbunden
# Actual English Translation:  but the talibans rapid rise in the s was inextricably linked to the failure of irrigation systems
# Predicted English Translation:  but the talibans rapid rise in the s was inextric
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: doch die zahlen bleiben noch recht klein
# Actual English Translation:  but the numbers remain very small
# Predicted English Translation:  but the numbers remain very small
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: doch leidet die eu an einem übermaß an visionen und einem mangel an praktischen haushaltsmaßnahmen
# Actual English Translation:  but the eu has suffered from a surfeit of vision and a deficit of practical budgetary measures
# Predicted English Translation:  but the eu has suffered from a surfeit of democ
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ich glaube dass sich herausstellen wird dass sie unrecht haben
# Actual English Translation:  i believe that they will be proved wrong
# Predicted English Translation:  i believe that they will not accept the same
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ohne über das jahr hinausgehende regulierungsmaßnahmen würden sich nach  keine gelegenheiten für projektgebundene transaktionen mehr ergeben
# Actual English Translation:  without a regulatory framework beyond  the window of opportunity for initiating projectbased transactions will close by
# Predicted English Translation:  without a lot of multilateral weapons however m
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: komplizierte strategische wechselbeziehungen gibt es nicht nur zwischen israelis und palästinensern sondern auch innerhalb der beiden lager
# Actual English Translation:  complicated strategic interactions exist not only between israelis and palestinians but also within the two sides
# Predicted English Translation:  complicated strategic interactions between power
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die gegenwärtigen aktionen argentiniens könnten uns schneller in das  jahrhundert zurück befördern als einigen investoren lieb ist
# Actual English Translation:  argentinas current actions may drive us back to the th century more quickly than some investors would like
# Predicted English Translation:  the second advanced of the us household consump
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: atmosphärisches co ist daher vermutlich auch der maßgebliche faktor im kommenden jahrhundert
# Actual English Translation:  atmospheric co is therefore presumably the controlling factor for the coming century as well
# Predicted English Translation:  atmospheric co is the heart that it has made a wo
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: als ich einen platz an einer medizinischen fakultät in deutschland bekam waren meine eltern stolz
# Actual English Translation:  when i won a place at a medical college in germany my parents were proud
# Predicted English Translation:  when i won a much at different a medical colleg
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: deshalb sind internationale maßnahmen erforderlich um sowohl armut als auch globale ungleichheit anzugehen
# Actual English Translation:  this is why international action to address both global poverty and global inequality is needed
# Predicted English Translation:  all these countries are barred with large sanct
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die gefahr für diese welt ist dass putins gesetzlosigkeit exportiert wird
# Actual English Translation:  the danger for the world is that putins lawlessness is being exported
# Predicted English Translation:  the danger for the us is that putins lawlessnes
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: welche art von kraftwerken werden in der zukunft akzeptabel sein
# Actual English Translation:  what kinds of power plants will be acceptable in the future
# Predicted English Translation:  what kinds of power plants will be acceptable in
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die zweite bekannte schwäche von familienunternehmen ist das problem der nachfolge
# Actual English Translation:  the second notorious weakness of family businesses is the problem of succession
# Predicted English Translation:  the second notorious weakness of the end is the p
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: ·        entwicklung internationaler und multilateraler ansätze um den risiken der brennstoffproduktion für zivile kernkraft zu begegnen
# Actual English Translation:  ·        developing international and multilateral approaches to manage the risks of fuel production for civilian nuclear power and
# Predicted English Translation:  · developing countries and more than chinas poli
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die neue agenda muss außerdem eine starke wirtschaftliche komponente umfassen
# Actual English Translation:  the new agenda must also include a strong economic component
# Predicted English Translation:  the european agenda must also include a new econ
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: auch die stationäre pflege wurde drastisch gekürzt
# Actual English Translation:  inpatient care too has been slashed
# Predicted English Translation:  inpatient care too has been slashed
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: der fortschritt hinsichtlich des inflationsrückgangs ist ähnlich beeindruckend
# Actual English Translation:  progress on disinflation is similarly impressive
# Predicted English Translation:  progress on disinflation is similarly impressive
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: in jedem dieser  jahre lag die sparquote zwischen   und
# Actual English Translation:  the saving rate in each of those years was between  and
# Predicted English Translation:  by the current fiscal year i had been increasi
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die malediven werden wahrscheinlich ganz verschwinden
# Actual English Translation:  the maldives will likely disappear entirely
# Predicted English Translation:  the maldives will likely disappear entirely
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diese art von diplomatie ist weder schnell noch einfach
# Actual English Translation:  this brand of diplomacy is not quick or easy
# Predicted English Translation:  this brand of diplomacy is not quick or easy
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: dies hätte die sternstunde der europäer sein können
# Actual English Translation:  this could have been europes moment
# Predicted English Translation:  this could have been europes moment
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die muttergesellschaft möchte diese mittel nun verwenden um die liquidität des konzerns zu stärken
# Actual English Translation:  the parent bank would like to use these funds to reinforce the groups liquidity
# Predicted English Translation:  the parent bank would to use these funds to reinf
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: diesen muss man sich widmen wenn afghanistan wiederbelebt werden soll
# Actual English Translation:  these must be addressed if afghanistan is to be revived
# Predicted English Translation:  these must be addressed if the right to manage prob
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: doch es gibt nichts was einen weiter gehenden preissturz verhindern könnte wenn dieser punkt erst einmal erreicht ist
# Actual English Translation:  but there is nothing to stop the decline from continuing once it reaches that point
# Predicted English Translation:  but there is no better option to change these
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: war nicht italien bis in die er jahre des  jahrhunderts eine ansammlung von königreichen und fürstentümern
# Actual English Translation:  after all wasnt italy until s a collection of kingdoms and principalities
# Predicted English Translation:  after all wasnt italy from europe otherwise was increasi
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das ist momentan die wichtigste strategische frage für die vereinigten staaten
# Actual English Translation:  for the united states that is now the primary strategic question
# Predicted English Translation:  that is the first to hold the united states is in
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: und  machiavelli machte deutlich dass ein fürst hass unter allen umständen vermeiden sollte
# Actual English Translation:  and machiavelli made it clear that hatred is something a prince should carefully avoid
# Predicted English Translation:  and machiavelli made a lot of blind chance for
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: im falle eines scheiterns diplomatischer bemühungen werden china und russland wohl keine weiteren sanktionen gegen den iran unterstützen
# Actual English Translation:  china and russia seem unlikely to support any further sanctions against iran if diplomacy fails
# Predicted English Translation:  china and russia have even less religious if any pu
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: in großbritannien präsentieren sich neuere umfrageergebnisse als zweideutig
# Actual English Translation:  in the united kingdom recent survey results are ambiguous
# Predicted English Translation:  in the united kingdom recent survey results are ambig
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: obwohl weder hu noch wen direkt in die niederschlagung der proteste involviert waren müssen sie nun behutsam vorgehen
# Actual English Translation:  although neither hu nor wen were directly involved in the crackdown they nonetheless must tread carefully
# Predicted English Translation:  although neither hu nor wen were directly invo
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: das vertrauen in politische eliten und in nationale und europäische institute fällt stetig
# Actual English Translation:  trust in political elites and in national and european institutions has been steadily declining
# Predicted English Translation:  political in political elites and in rich and the en
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: seit ist die ethanolproduktion um  gestiegen
# Actual English Translation:  since  ethanol production has increased by
# Predicted English Translation:  since ethanol production has increased by
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: der klimawandel ist nicht das einzige problem vor dem die welt heute steht
# Actual English Translation:  climate change is not the only problem facing the globe
# Predicted English Translation:  climate change is not the only problem facing the g
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: im parlament des landes sitzen warlords zuhauf der drogenhandel blüht und die gewalt nimmt zu
# Actual English Translation:  the countrys parliament is packed with warlords the drug trade is thriving and violence is on the rise
# Predicted English Translation:  the countrys parliament is packed with warlords
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die sanierung des nigerdeltas wäre das bestmögliche beispiel für ein neues zeitalter der rechenschaftspflicht
# Actual English Translation:  cleaning up the niger delta would provide the strongest possible example of a new age of accountability
# Predicted English Translation:  cleaning up the niger delta would provide the stron
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: unterdessen bewirkten finanzinnovationen dass kredite immer billiger und leichter verfügbar wurden
# Actual English Translation:  financial innovation meanwhile worked to make credit even cheaper and more widely available
# Predicted English Translation:  financial innovation meanwhile worked to only
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: intellektuelle klagten darüber dass zu wenig zeit und energie auf die vergangenheitsbewältigung verwendet wurde
# Actual English Translation:  intellectuals complained that too little time and energy was spent on mastering the past
# Predicted English Translation:  intellectuals complained that too little count
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: unglücklicherweise sind unsere gegenwärtigen nachweismethoden dazu nicht empfindlich genug
# Actual English Translation:  unfortunately our present methods of detection are not sensitive enough
# Predicted English Translation:  unfortunately our other methods of detection are
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: starben etwa millionen kinder unter fünf jahren
# Actual English Translation:  around million children under five years old died in
# Predicted English Translation:  around million people in the surface three years
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: korruption beispielsweise kann bestandteil kultureller tradition sein und teil institutioneller schwäche
# Actual English Translation:  corruption for example may have cultural antecedents and is part and parcel of institutional weakness
# Predicted English Translation:  corruption for example may have united and finan
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die usa sollten eine internationale afghanistankonferenz unter schirmherrschaft der uno einberufen
# Actual English Translation:  an international conference on afghanistan should be called by the us and held under un auspices
# Predicted English Translation:  an international conference on afghanistan shoul
# ---------------------------------------------------------------------------------
# Input Deutsch sentence: die armen sich nicht abgesichert
# Actual English Translation:  the poor go unprotected
# Predicted English Translation:  the poor go unprotected
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## GRAPH AND COMPUTATION TIME

# %%
print("Total Computation Time : ", sum(time_callback.times))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
fig = plt.figure()
plt.show()
# Out:
# Total Computation Time :  1134.2775058746338

# %%
score = corpus_bleu(ref, can)
print("BLEU Score LSTM : ", score)
# Out:
# BLEU Score LSTM :  0.32309176870194567
